# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_excel("./data/(FPT Software)Excecise_todo.xlsx",header=1)
df.head()
# Out:
#    No             Hẹn Test           Full name        DOB Gender        SĐT   \
# 0   1  2020-10-28 00:00:00    Nguyễn Thế Quyền 1998-10-29    Nam  0393923282
# 1   2  2020-10-28 00:00:00    Nguyễn Việt Hưng 1998-06-16    Nam  0993031033
# 2   3  2020-10-28 00:00:00        Đào Văn Dũng 1992-12-12    Nam  0933909112
# 3   4  2020-10-28 00:00:00      Phạm Ngọc Nhật 1997-11-06    Nam  0339182891
# 4   5  2020-10-28 00:00:00  Bùi Doãn Minh Châu 1997-11-07    Nam  0889889019
#
#                        Email  University Major  Graduate  GPA    RECer  \
# 0        tkeqyyevd2@gmail.com       HDIU  CNTT    2020.0  2.8  DatNV20
# 1    kyvgvvse03303@fpt.edy.vv         FU  CNTT    2020.0  7.3  DatNV20
# 2        dyvgdevfpt@gmail.com       Poly  CNTT    2020.0  2.7  DatNV20
# 3  pkamvkat03333997@gmail.com       Poly  CNTT    2020.0  2.7  DatNV20
# 4        bdmckay303@gmail.com     HUTECH  CNTT    2022.0  2.7  DatNV20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No            87 non-null     int64
#  1   Hẹn Test      87 non-null     object
#  2   Full name     87 non-null     object
#  3   DOB           87 non-null     datetime64[ns]
#  4   Gender        87 non-null     object
#  5   SĐT           87 non-null     object
#  6   Email         87 non-null     object
#  7   University    87 non-null     object
#  8   Major         85 non-null     object
#  9   Graduate      86 non-null     float64
#  10  GPA           87 non-null     float64
#  11  RECer         87 non-null     object
#  12  Chanel        87 non-null     object
#  13  Working time  87 non-null     object
#  14  Tech          87 non-null     object
#  15  Language      87 non-null     object
#  16  Date          87 non-null     datetime64[ns]
# ...
